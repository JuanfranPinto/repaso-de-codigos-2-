# %% [markdown]
# # Splines cúbicos

# %%
def Spline(x: float, x0: float, pars: dict[str, float]) -> float:
    a = pars["a"]
    b = pars["b"]
    c = pars["c"]
    d = pars["d"]
    return a + b * (x - x0) + c * (x - x0) ** 2 + d * (x - x0) ** 3

# %%
import matplotlib.pyplot as plt
import numpy as np

xs = [-1, 0, 1]
ys = [1, 5, 3]
s = [
    {"a": 1, "b": 5.5, "c": 0, "d": -1.5},
    {"a": 5, "b": 1, "c": -4.5, "d": 1.5},
]
for i, x_i in enumerate(xs[:-1]):
    _x = np.linspace(x_i, xs[i + 1], 20)
    _y = Spline(_x, x_i, s[i])
    plt.plot(_x, _y, color="red")

plt.scatter(xs, ys)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolación con splines cúbicos")
plt.show()

# %% [markdown]
# # Tarea
# * Grafique los splines cúbicos tal que cumplan con la pendiente $m$ deseada en el punto $(x_1,y_1)$.

# %% [markdown]
# Con frontera natura

# %%
from src import eliminacion_gaussiana, matriz_aumentada, gauss_seidel
import numpy as np
## encontrar [b0, d0, c1, d1] = b[]
A = np.array([[1,1,0,0],[0,0,1,1],[1,3,0,0],[0,0,2,6]])

b = np.array([4,0,-2,0])

Ab = matriz_aumentada(A,b)
print('soluciones', eliminacion_gaussiana(Ab))
# Out:
# [02-09 13:04:16][INFO][pc]
# [[ 1  1  0  0  4]
#  [ 0  0  1  1  0]
#  [ 0  2  0  0 -6]
#  [ 0  0  2  6  0]]
# [02-09 13:04:16][INFO][pc]
# [[ 1  1  0  0  4]
#  [ 0  2  0  0 -6]
#  [ 0  0  1  1  0]
#  [ 0  0  2  6  0]]
# [02-09 13:04:16][INFO][pc]
# [[ 1  1  0  0  4]
#  [ 0  2  0  0 -6]
#  [ 0  0  1  1  0]
#  [ 0  0  0  4  0]]
# soluciones [ 7. -3.  0.  0.]

# %%
def Spline(x: float, x0: float, pars: dict[str, float]) -> float:
    a = pars["a"]
    b = pars["b"]
    c = pars["c"]
    d = pars["d"]
    return a + b * (x - x0) + c * (x - x0) ** 2 + d * (x - x0) ** 3

# %%
import matplotlib.pyplot as plt
import numpy as np

def recta_pendiente(x):
    x1 = -2*x +5
    return x1

xs = [-1, 0, 1]
ys = [1, 5, 3]
s = [
    {"a": 1, "b": 7, "c": 0, "d": -3},
    {"a": 5, "b": -2, "c": 0, "d": 0},
]
for i, x_i in enumerate(xs[:-1]):
    _x = np.linspace(x_i, xs[i + 1], 20)
    _y = Spline(_x, x_i, s[i])
    plt.plot(_x, _y, color="red")
   
plt.scatter(xs, ys)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolación con splines cúbicos")
x = np.linspace(-1, 1, 20)
y = recta_pendiente(x)
plt.plot(x, y, color="blue", linestyle="--")
